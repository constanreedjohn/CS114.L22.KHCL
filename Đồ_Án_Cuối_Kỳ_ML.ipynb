# %% [markdown]
# # CS114.L22.KHCL - Giảng viên: Phạm Nguyễn Trường An, Lê Đình Duy
# ## Nhóm:
# 1. Lê Trần Trọng Khiêm - 19521689
# 2. Trần Tiến Hưng - 19521587
# 3. Lê Đặng Đăng Huy - 19521612
#
# # **ĐỒ ÁN CUỐI KỲ**
#
# # **1. Mô tả bài toán:**
# > Hiện nay các bài toán nhận diện chữ đều thể hiện khá tốt trong điều kiện ánh sáng không quá phức tạp. Tuy nhiên khi ánh sáng trở nên phức tạp như ban đêm, các bảng hiệu neon lại bị chói nên khó cho nhận diện.
#
# > Vì thế tụi em muốn sử dụng các thuật toán Machine Learing để có thể nhận dạng các nội dung trong các bảng hiệu với điều kiện phức tạp về các bảng hiệu neon vào ban đêm.
#
# > Ứng dụng của việc là các bảng hiệu neon vào ban đêm sẽ hỗ trợ được rất nhiệu cho các bài toán như Image captioning, Visual Question Answering...
#
# > **INPUT:** Hình ảnh của một bảng hiệu neon trong ban đêm với góc chụp trực diện.
#
# > **OUTPUT:** Chữ nhận dạng được từ nội dung bảng hiệu.
#
# # **2. Mô tả về dataset:**
# > **Cách thức xây dựng dataset:**
# >> Về cách xây dựng dataset thì tụi em sẽ crawl data trên google hoặc đi chụp hình thực tiễn.
#
# > **Số lượng, độ đa dạng:**
# >> Số lượng dataset của tụi em tổng sẽ là 3000 hình, split train/test theo 80/20.
# >> Độ đa dạng sẽ tập trung chủ yếu vào các bức ảnh NEON chụp trực diện, vào buổi tối.
#
# # **Lưu ý:**
# > Bài toán này hiện tại là một bài toán rất bao quát, với nhiều trường hợp biến cố xảy ra với data như thiếu độ sáng, bảng bị cong, góc chụp... Vì thế tụi em được hướng dẫn là sẽ chọn 1 trường hợp cụ thể để thực hiện đồ án.
#
# > Trường hợp data của tụi em sẽ là:
# 1. Góc chụp: Trực diện
# 2. Môi trường: Buổi tối
# 3. Trạng thái bảng hiệu: các bảng hiệu có đèn NEON, LED.
#
#
# # **3. Mô tả về xử lý dữ liệu**
#
# <img src="https://lambienled.com/wp-content/uploads/2019/12/bang-hieu-led-do-%C4%83n-vat-1.jpg">
#
# > Trước hết tụi em sẽ crop các chữ trong hình để có thể khoanh vùng chữ.

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2
img_1 = cv2.imread('/content/BANHBEO.jpg')
img_2 = cv2.imread('/content/BUNRIEUOC.jpg')
img_3 = cv2.imread('/content/TRASUA.jpg')

cv2_imshow(img_1)
cv2_imshow(img_2)
cv2_imshow(img_3)
# Out:
# <PIL.Image.Image image mode=RGB size=436x143 at 0x7F59AEB2B590>
# <PIL.Image.Image image mode=RGB size=509x117 at 0x7F59AEC517D0>
# <PIL.Image.Image image mode=RGB size=386x115 at 0x7F59AEC510D0>

# %% [markdown]
# > Sau đó tụi em sẽ đánh label cho các crop khung:
#
# > Ví dụ: "BÁNH BÈO", "BÚN RIÊU ỐC", "TRÀ SỮA".

# %% [markdown]
# > Cuối cùng tụi em sẽ sử dụng model regconition SOTA như VietOCR...
# và kết quả output sẽ cho ra.

# %%
res = cv2.imread("/content/result.jpg")
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x447 at 0x7F59AEC51ED0>

# %% [markdown]
# ## Tụi em sẽ đánh giá model qua các thang đo như accuracy, Levenshtein distance
